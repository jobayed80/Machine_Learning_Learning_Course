# %% [markdown]
# <a href="https://colab.research.google.com/github/jobayed80/Machine_Learning_Learning_Course/blob/main/Machine_Learning_DataFrame_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
# This part of Empty DataFrame.
df

# %%
#Now create a list
city = ['Dhaka', 'Feni', 'Kishoregang', 'Sylhet', 'Mymensingh']
city
# Out:
# ['Dhaka', 'Feni', 'Kishoregang', 'Sylhet', 'Mymensingh']

# %%
#The list assigned to be in DataFrame
df = pd.DataFrame(city)
df
# Out:
#              0
# 0        Dhaka
# 1         Feni
# 2  Kishoregang
# 3       Sylhet
# 4   Mymensingh

# %%
type(city)
# Out:
# list

# %%
#Here can see that in the list not defined colimns name. so, defined of being columns.
df = pd.DataFrame(city , columns=['City_Name_List'])
df
# Out:
#   City_Name_List
# 0          Dhaka
# 1           Feni
# 2    Kishoregang
# 3         Sylhet
# 4     Mymensingh

# %%
df.shape
# Out:
# (5, 1)

# %%
row , col = df.shape

# %%
row
# Out:
# 5

# %%
col
# Out:
# 1

# %%
#Here defined of being rows.
df = pd.DataFrame(city, columns=['City_Name_list'], index=['City-1', 'City-2', 'City-3', 'City-4', 'City-5'])

# %%
df
# Out:
#        City_Name_list
# City-1          Dhaka
# City-2           Feni
# City-3    Kishoregang
# City-4         Sylhet
# City-5     Mymensingh

# %%
name = ['Jobayed', 'Hossain', 'Rabbi' , 'Noushin', 'Zaina']

# %%
name
# Out:
# ['Jobayed', 'Hossain', 'Rabbi', 'Noushin', 'Zaina']

# %%
#merge 2 list
df2 = pd.DataFrame(zip(city , name) , columns=['City_Name' , 'Full_Name'])

# %%
df2
# Out:
#      City_Name Full_Name
# 0        Dhaka   Jobayed
# 1         Feni   Hossain
# 2  Kishoregang     Rabbi
# 3       Sylhet   Noushin
# 4   Mymensingh     Zaina

# %%
df2 = pd.DataFrame(zip(city, name), columns=['City_Name_List', 'Name_List'] , index=['Num-1','Num-2', 'Num-3',' Num-4','Num-5'])

# %%
df2
# Out:
#        City_Name_List Name_List
# Num-1           Dhaka   Jobayed
# Num-2            Feni   Hossain
# Num-3     Kishoregang     Rabbi
#  Num-4         Sylhet   Noushin
# Num-5      Mymensingh     Zaina

# %%
df2.shape
# Out:
# (5, 2)

# %%
# I have 2 dimensional data
details = [['20', '01643897838'] , ['23' , '01943897838'] , ['25', '01743897838'],
       ['26', '01843897838'] ,  ['28' , '01543897838']]

# %%
df3 = pd.DataFrame(details , columns= ['Age' , 'Contact'])
df3
# Out:
#   Age      Contact
# 0  20  01643897838
# 1  23  01943897838
# 2  25  01743897838
# 3  26  01843897838
# 4  28  01543897838

# %%
merge_df = pd.DataFrame(zip(city,name,details))

# %%
merge_df
# Out:
#        0        1        2
# 0  Dhaka  Jobayed      Age
# 1   Feni  Hossain  Contact

# %%
city
# Out:
# ['Dhaka', 'Feni', 'Kishoregang', 'Sylhet', 'Mymensingh']

# %%
name
# Out:
# ['Jobayed', 'Hossain', 'Rabbi', 'Noushin', 'Zaina']

# %%
details
# Out:
# [['20', '01643897838'],
#  ['23', '01943897838'],
#  ['25', '01743897838'],
#  ['26', '01843897838'],
#  ['28', '01543897838']]

# %%
#used of dictionary function
dict1 = {
  'City' : city,
  'Name' : name,
  'Details' : details
}

# %%
dict1
# Out:
# {'City': ['Dhaka', 'Feni', 'Kishoregang', 'Sylhet', 'Mymensingh'],
#  'Name': ['Jobayed', 'Hossain', 'Rabbi', 'Noushin', 'Zaina'],
#  'Details': [['20', '01643897838'],
#   ['23', '01943897838'],
#   ['25', '01743897838'],
#   ['26', '01843897838'],
#   ['28', '01543897838']]}

# %%
df_dict = pd.DataFrame(dict1 , index=['S-1', 'S-2','S-3','S-4','S-5'])

# %%
df_dict
# Out:
#             City     Name            Details
# S-1        Dhaka  Jobayed  [20, 01643897838]
# S-2         Feni  Hossain  [23, 01943897838]
# S-3  Kishoregang    Rabbi  [25, 01743897838]
# S-4       Sylhet  Noushin  [26, 01843897838]
# S-5   Mymensingh    Zaina  [28, 01543897838]

# %%
df_dict.shape
# Out:
# (5, 3)
